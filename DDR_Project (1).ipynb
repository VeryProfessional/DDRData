# %% [markdown]
# # DDR_Project

# %% [markdown]
# # Setup
#
# ## Library import
# We import all the required Python libraries

# %%
# Data manipulation
import pandas as pd
import numpy as np

import seaborn as sns

# Options for pandas
pd.options.display.max_columns = 50
pd.options.display.max_rows = 30

# Visualizations
import plotly
import plotly.graph_objs as go
import plotly.offline as ply
plotly.offline.init_notebook_mode(connected=True)

#import cufflinks as cf
#cf.go_offline(connected=True)
#cf.set_config_file(theme='white')

import matplotlib
matplotlib.use
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# Autoreload extension
if 'autoreload' not in get_ipython().extension_manager.loaded:
    # %load_ext autoreload
    
# %autoreload 2
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Local library import
# We import all the required local libraries libraries

# %%
# Include local library paths
import sys
# sys.path.append('path/to/local/lib') # uncomment and fill to import local libraries

# Import local libraries

# %% [markdown]
# # Parameter definition
# We set all relevant parameters for our notebook. By convention, parameters are uppercase, while all the
# other variables follow Python's guidelines.

# %% [markdown]
# # Data import
# We retrieve all the required data for the analysis.

# %% [markdown]
# # Data processing
# Put here the core of the notebook. Feel free di further split this section into subsections.

# %% [markdown]
# # References
# We report here relevant references:
# 1. author1, article1, journal1, year1, url1
# 2. author2, article2, journal2, year2, url2

# %%
df_Song = pd.read_excel("/Users/annettechiu/Downloads/DDR_Project.xlsx")

# %%
df_Users = pd.read_excel("/Users/annettechiu/Downloads/DDR_Project_1.xlsx")
df_Users.head()
# Out:
#             Users Name   CHRS4LFE     FEFEMZ       o4ma     Fungah    MMAGDON  \
# 0              User ID          A          B          C          D          E
# 1             DDR code  5140-9674  4113-0109  1104-8753  4106-9894  5141-5536
# 2    Country of origin        USA      Korea      Japan        USA        USA
# 3  Years of experience         15         >7        >13         16         >9
# 4  #of KAC appearances          4          5          8          3          0
#
#      KAZE573     Chunka      Kevbo    HO4KETI        RSS      Hades  \
# 0          F          G          H          I          J          K
# 1  4120-5830  4130-4291  5141-4293  1105-8239  4118-7437  4125-7645
# 2        USA        USA        USA      Japan      Korea      Japan
# 3        >12        >14        >12         >2         >4         >5
# 4          0          0          0          1          1          0
#
#      ITGALEX      YUDAI   ZEROWOLF HIBIKI
# 0          L          M          N      O
# ...

# %%
df_Players = pd.read_excel("/Users/annettechiu/Downloads/DDR_Project_2.xlsx")
df_Players.head()
# Out:
#                   X=song Y=Player   CHRS4LFE    FEFEMZ      o4ma    Fungah  \
# 0                      Air Heroes   999970.0  999780.0  999830.0  999960.0
# 1  Fascination ~eternal love mix~  1000000.0  999750.0  999850.0  999770.0
# 2                    Come to Life   999930.0  999770.0  999840.0  999920.0
# 3             PARANOiA Revolution   999890.0  999880.0  999800.0  999840.0
# 4                            Prey   999960.0       NaN  999980.0  999890.0
#
#     MMAGDON   KAZE573    Chunka     Kevbo   HO4KETI       RSS     Hades  \
# 0  999760.0  999900.0  999870.0  999850.0  999630.0  999690.0  999540.0
# 1  999740.0  999720.0  999800.0  999710.0  999760.0  999460.0  999360.0
# 2  999550.0  999890.0  999890.0  999800.0  999810.0  999480.0  999260.0
# 3  999520.0  999780.0  999700.0  999810.0  999680.0  999550.0  999740.0
# 4  999950.0  999860.0  999950.0  999870.0  999630.0  999620.0  999410.0
#
#     ITGALEX     YUDAI  ZEROWOLF    HIBIKI  Highest score  Average score  \
# ...

# %%
df_Song.describe(include=['O'])
# Out:
#                          Song
# count                      53
# unique                     45
# top     Lachryma (Re:Queen'M)
# freq                        2

# %%
df_Users.describe(include=['O'])
# Out:
#        Users Name  CHRS4LFE FEFEMZ o4ma     Fungah MMAGDON KAZE573  \
# count           6         6      6    6          6       6       6
# unique          6         6      6    6          6       6       6
# top         Notes        15     >7    C  4106-9894       E       F
# freq            1         1      1    1          1       1       1
#
#                                                    Chunka              Kevbo  \
# count                                                   6                  6
# unique                                                  6                  6
# top     Third person to PFC all 18's, currently improv...  Has FC'd every 18
# freq                                                    1                  1
#
#                                                   HO4KETI RSS Hades  \
# count                                                   6   6     6
# unique                                                  6   6     6
# ...

# %%
df_Players.describe(include=['O'])
# Out:
#               X=song Y=Player
# count                      54
# unique                     46
# top     Lachryma (Re:Queen'M)
# freq                        2

# %%
# feature display
import math
def plot_distribution(dataset, cols=5, width=20, height=15, hspace=0.2, wspace=0.5):
    plt.style.use('seaborn-whitegrid')
    fig = plt.figure(figsize=(width,height))
    fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)
    rows = math.ceil(float(dataset.shape[1]) / cols)
    for i, column in enumerate(dataset.columns):
        ax = fig.add_subplot(rows, cols, i + 1)
        ax.set_title(column)
        if dataset.dtypes[column] == np.object:
            g = sns.countplot(y=column, data=dataset)
            substrings = [s.get_text()[:18] for s in g.get_yticklabels()]
            g.set(yticklabels=substrings)
            plt.xticks(rotation=25)
        else:
            #plot
            g = sns.distplot(dataset[column])
            plt.xticks(rotation=25)
    
plot_distribution(df_Song, cols=3, width=20, height=20, hspace=0.45, wspace=0.5)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning:
#
# Default bandwidth for data is 0; skipping density estimation.
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning:
#
# Default bandwidth for data is 0; skipping density estimation.
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning:
#
# Glyph 12471 missing from current font.
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning:
#
# Glyph 12517 missing from current font.
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning:
#
# Glyph 12524 missing from current font.
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning:
#
# Glyph 12540 missing from current font.
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning:
#
# ...

# %%
# feature display
import math
def plot_distribution(dataset, cols=5, width=20, height=15, hspace=0.2, wspace=0.5):
    plt.style.use('seaborn-whitegrid')
    fig = plt.figure(figsize=(width,height))
    fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)
    rows = math.ceil(float(dataset.shape[1]) / cols)
    for i, column in enumerate(dataset.columns):
        ax = fig.add_subplot(rows, cols, i + 1)
        ax.set_title(column)
        if dataset.dtypes[column] == np.object:
            g = sns.countplot(y=column, data=dataset)
            substrings = [s.get_text()[:18] for s in g.get_yticklabels()]
            g.set(yticklabels=substrings)
            plt.xticks(rotation=25)
        else:
            #plot
            g = sns.distplot(dataset[column])
            plt.xticks(rotation=25)
    
plot_distribution(df_Song, cols=3, width=20, height=20, hspace=0.45, wspace=0.5)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning:
#
# Default bandwidth for data is 0; skipping density estimation.
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:369: UserWarning:
#
# Default bandwidth for data is 0; skipping density estimation.

# %%
import seaborn as sns

# %%
# feature display
import math
def plot_distribution(dataset, cols=5, width=20, height=15, hspace=0.2, wspace=0.5):
    plt.style.use('seaborn-whitegrid')
    fig = plt.figure(figsize=(width,height))
    fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)
    rows = math.ceil(float(dataset.shape[1]) / cols)
    for i, column in enumerate(dataset.columns):
        ax = fig.add_subplot(rows, cols, i + 1)
        ax.set_title(column)
        if dataset.dtypes[column] == np.object:
            g = sns.countplot(y=column, data=dataset)
            substrings = [s.get_text()[:18] for s in g.get_yticklabels()]
            g.set(yticklabels=substrings)
            plt.xticks(rotation=25)
        else:
            #plot
            g = sns.distplot(dataset[column])
            plt.xticks(rotation=25)
    
plot_distribution(df_Users, cols=3, width=20, height=20, hspace=0.45, wspace=0.5)

# %%
# 创建两个数据集的相关图s.
plt.style.use('seaborn-whitegrid')
fig = plt.figure(figsize=(25,10)) 

plt.subplot(1, 2, 1)

mask = np.zeros_like(df_Players.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(df_Players.corr(), 
            vmin=-1, vmax=1, 
            square=True, 
            cmap=sns.color_palette("RdBu_r", 100), 
            mask=mask, 
            linewidths=.5);

plt.subplot(1, 2, 2)
mask = np.zeros_like(df_Song.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(df_Song.corr(), 
            vmin=-1, vmax=1, 
            square=True, 
            cmap=sns.color_palette("RdBu_r", 100), 
            mask=mask, 
            linewidths=.5);

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
df_Users.shape
# Out:
# (6, 16)

# %%
from scipy.stats import pearsonr
np.random.rand(0)
size=300
x=np.random.normal(0,1,size)
#pearsonr(x,y)的輸入為特徵矩陣和目標向量
#pearsonr的輸出分別為pearson相關係數和p-value
print('Lower noise',pearsonr(x,x+np.random.normal(0,1,size)))
print('High noise',pearsonr(x,x+np.random.normal(0,10,size)))
# Out:
# Lower noise (0.7135189535586438, 5.840007807254601e-48)
# High noise (0.16893976174977987, 0.003335135517807714)

# %%
from sklearn.feature_selection import SelectKBest

# %%
df_Song.head()
# Out:
#                              Song  ID  Length (seconds)  Notes  Freeze Arrows  \
# 0                      Air Heroes   1                97    622             35
# 1  Fascination ~eternal love mix~   2               101    572             14
# 2                    Come to Life   3               120    730             70
# 3             PARANOiA Revolution   4               111    679             20
# 4                            Prey   5               100    633             10
#
#    Shock Arrows       Jumps  BPM  Peak BPM  Lowest BPM  # of Stops  \
# 0             0   25.785833  175       175         175           0
# 1             0  107.901667  200       400         100          13
# 2             0   55.000000  180       180          90           0
# 3             0   59.015000  180       360         180           1
# 4             0   24.750000  210       210         210           0
#
#    # BPM changes  Notes/Second  Year of Origin  #of Crossovers  Difficulty  \
# ...

# %%
#Drop Columns in Pandas
df_Song.drop(['Song'], axis='columns', inplace=True)

# %%
#Removing features with low variance
from sklearn.feature_selection import VarianceThreshold
#X=np.array([[0,0,1],[0,1,0],[1,0,0],[0,1,1],[0,1,0],[0,1,1]])
#閥值(threshold)為0.16,表示其變異程度低於0.16就會被removed
X = df_Song
variance_x=VarianceThreshold(threshold=0.50)
variance_x.fit_transform(X)
# Out:
# array([[1.00000000e+00, 9.70000000e+01, 6.22000000e+02, 3.50000000e+01,
#         0.00000000e+00, 2.57858333e+01, 1.75000000e+02, 1.75000000e+02,
#         1.75000000e+02, 0.00000000e+00, 0.00000000e+00, 6.41237113e+00,
#         2.01300000e+03, 1.40000000e+01, 2.90000000e+01],
#        [2.00000000e+00, 1.01000000e+02, 5.72000000e+02, 1.40000000e+01,
#         0.00000000e+00, 1.07901667e+02, 2.00000000e+02, 4.00000000e+02,
#         1.00000000e+02, 1.30000000e+01, 8.00000000e+00, 5.66336634e+00,
#         2.00600000e+03, 0.00000000e+00, 1.10000000e+02],
#        [3.00000000e+00, 1.20000000e+02, 7.30000000e+02, 7.00000000e+01,
#         0.00000000e+00, 5.50000000e+01, 1.80000000e+02, 1.80000000e+02,
#         9.00000000e+01, 0.00000000e+00, 3.00000000e+00, 6.08333333e+00,
#         2.01600000e+03, 1.20000000e+01, 5.00000000e+01],
#        [4.00000000e+00, 1.11000000e+02, 6.79000000e+02, 2.00000000e+01,
#         0.00000000e+00, 5.90150000e+01, 1.80000000e+02, 3.60000000e+02,
# ...

# %%
df_Song.head()
# Out:
#    ID  Length (seconds)  Notes  Freeze Arrows  Shock Arrows       Jumps  BPM  \
# 0   1                97    622             35             0   25.785833  175
# 1   2               101    572             14             0  107.901667  200
# 2   3               120    730             70             0   55.000000  180
# 3   4               111    679             20             0   59.015000  180
# 4   5               100    633             10             0   24.750000  210
#
#    Peak BPM  Lowest BPM  # of Stops  # BPM changes  Notes/Second  \
# 0       175         175           0              0      6.412371
# 1       400         100          13              8      5.663366
# 2       180          90           0              3      6.083333
# 3       360         180           1              2      6.117117
# 4       210         210           0              0      6.330000
#
#    Year of Origin  #of Crossovers  Difficulty  Air
# 0            2013              14          18   29
# ...

# %%
print(df_Song.keys())
# Out:
# Index(['ID', 'Length (seconds)', 'Notes', 'Freeze Arrows', 'Shock Arrows',
#        'Jumps', 'BPM', 'Peak BPM', 'Lowest BPM', '# of Stops', '# BPM changes',
#        'Notes/Second', 'Year of Origin', '#of Crossovers', 'Difficulty',
#        'Air'],
#       dtype='object')
